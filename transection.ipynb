# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# now creating data
import matplotlib.pyplot as plt
import pandas as pd
ADBL = pd.read_csv('ADBL.csv', usecols=['Total Transactions'],nrows=50)
ADBL = list(ADBL['Total Transactions'])

AHPC = pd.read_csv('AHPC.csv', usecols=['Total Transactions'],nrows =50)
AHPC= list(AHPC['Total Transactions'])

AKJCL = pd.read_csv('AKJCL.csv', usecols=['Total Transactions'],nrows = 50)
AKJCL = list(AKJCL['Total Transactions'])

AKPL = pd.read_csv('AKPL.csv', usecols=['Total Transactions'],nrows=50)
AKPL= list(AKPL['Total Transactions'])

# %%
# plotting the plot
# plt.plot(values)
plt.plot(ADBL)
plt.plot(AHPC)
plt.plot(AKJCL)
plt.plot(AKPL)
plt.show()
